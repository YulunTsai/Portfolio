# %%
pip install igdb-api-v4
# Out:
# Collecting igdb-api-v4
#   Downloading igdb_api_v4-0.3.3-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from igdb-api-v4) (2.32.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from igdb-api-v4) (5.29.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->igdb-api-v4) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->igdb-api-v4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->igdb-api-v4) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->igdb-api-v4) (2025.4.26)
# Downloading igdb_api_v4-0.3.3-py3-none-any.whl (15 kB)
# Installing collected packages: igdb-api-v4
# Successfully installed igdb-api-v4-0.3.3

# %%
from igdb.wrapper import IGDBWrapper
import json
import pandas as pd
import time

# %%
with open('igdb_credentials.json', 'r') as f:
    creds = json.load(f)

CLIENT_ID = creds['client_id']
ACCESS_TOKEN = creds['access_token']

# %%
wrapper = IGDBWrapper(CLIENT_ID, ACCESS_TOKEN)

# %%
all_games = []
offset = 0
limit = 500  # IGDB API only can get 500 row at one time

while True:
    query = f'''
    fields id, name, genres, game_type, first_release_date, aggregated_rating, aggregated_rating_count, rating, rating_count, total_rating, total_rating_count;
    where platforms = (6);
    limit {limit};
    offset {offset};
    '''

    byte_array = wrapper.api_request('games', query)
    games_batch = json.loads(byte_array.decode('utf-8'))

    if not games_batch:
        break

    all_games.extend(games_batch)
    offset += limit
    print(f'Fetched {len(games_batch)} games (total so far: {len(all_games)})')
    time.sleep(0.25)

print(f'Done! Total games fetched: {len(all_games)}')
# Out:
# Fetched 500 games (total so far: 500)
# Fetched 500 games (total so far: 1000)
# Fetched 500 games (total so far: 1500)
# Fetched 500 games (total so far: 2000)
# Fetched 500 games (total so far: 2500)
# Fetched 500 games (total so far: 3000)
# Fetched 500 games (total so far: 3500)
# Fetched 500 games (total so far: 4000)
# Fetched 500 games (total so far: 4500)
# Fetched 500 games (total so far: 5000)
# Fetched 500 games (total so far: 5500)
# Fetched 500 games (total so far: 6000)
# Fetched 500 games (total so far: 6500)
# Fetched 500 games (total so far: 7000)
# Fetched 500 games (total so far: 7500)
# Fetched 500 games (total so far: 8000)
# Fetched 500 games (total so far: 8500)
# Fetched 500 games (total so far: 9000)
# Fetched 500 games (total so far: 9500)
# Fetched 500 games (total so far: 10000)
# Fetched 500 games (total so far: 10500)
# Fetched 500 games (total so far: 11000)
# Fetched 500 games (total so far: 11500)
# Fetched 500 games (total so far: 12000)
# Fetched 500 games (total so far: 12500)
# Fetched 500 games (total so far: 13000)
# Fetched 500 games (total so far: 13500)
# Fetched 500 games (total so far: 14000)
# Fetched 500 games (total so far: 14500)
# Fetched 500 games (total so far: 15000)
# Fetched 500 games (total so far: 15500)
# Fetched 500 games (total so far: 16000)
# Fetched 500 games (total so far: 16500)
# Fetched 500 games (total so far: 17000)
# Fetched 500 games (total so far: 17500)
# Fetched 500 games (total so far: 18000)
# Fetched 500 games (total so far: 18500)
# Fetched 500 games (total so far: 19000)
# Fetched 500 games (total so far: 19500)
# Fetched 500 games (total so far: 20000)
# Fetched 500 games (total so far: 20500)
# Fetched 500 games (total so far: 21000)
# Fetched 500 games (total so far: 21500)
# Fetched 500 games (total so far: 22000)
# Fetched 500 games (total so far: 22500)
# Fetched 500 games (total so far: 23000)
# Fetched 500 games (total so far: 23500)
# Fetched 500 games (total so far: 24000)
# Fetched 500 games (total so far: 24500)
# Fetched 500 games (total so far: 25000)
# Fetched 500 games (total so far: 25500)
# Fetched 500 games (total so far: 26000)
# Fetched 500 games (total so far: 26500)
# Fetched 500 games (total so far: 27000)
# Fetched 500 games (total so far: 27500)
# Fetched 500 games (total so far: 28000)
# Fetched 500 games (total so far: 28500)
# Fetched 500 games (total so far: 29000)
# Fetched 500 games (total so far: 29500)
# Fetched 500 games (total so far: 30000)
# Fetched 500 games (total so far: 30500)
# Fetched 500 games (total so far: 31000)
# Fetched 500 games (total so far: 31500)
# Fetched 500 games (total so far: 32000)
# Fetched 500 games (total so far: 32500)
# Fetched 500 games (total so far: 33000)
# Fetched 500 games (total so far: 33500)
# Fetched 500 games (total so far: 34000)
# Fetched 500 games (total so far: 34500)
# Fetched 500 games (total so far: 35000)
# Fetched 500 games (total so far: 35500)
# Fetched 500 games (total so far: 36000)
# Fetched 500 games (total so far: 36500)
# Fetched 500 games (total so far: 37000)
# Fetched 500 games (total so far: 37500)
# Fetched 500 games (total so far: 38000)
# Fetched 500 games (total so far: 38500)
# Fetched 500 games (total so far: 39000)
# Fetched 500 games (total so far: 39500)
# Fetched 500 games (total so far: 40000)
# Fetched 500 games (total so far: 40500)
# Fetched 500 games (total so far: 41000)
# Fetched 500 games (total so far: 41500)
# Fetched 500 games (total so far: 42000)
# Fetched 500 games (total so far: 42500)
# Fetched 500 games (total so far: 43000)
# Fetched 500 games (total so far: 43500)
# Fetched 500 games (total so far: 44000)
# Fetched 500 games (total so far: 44500)
# Fetched 500 games (total so far: 45000)
# Fetched 500 games (total so far: 45500)
# Fetched 500 games (total so far: 46000)
# Fetched 500 games (total so far: 46500)
# Fetched 500 games (total so far: 47000)
# Fetched 500 games (total so far: 47500)
# Fetched 500 games (total so far: 48000)
# Fetched 500 games (total so far: 48500)
# Fetched 500 games (total so far: 49000)
# Fetched 500 games (total so far: 49500)
# Fetched 500 games (total so far: 50000)
# Fetched 500 games (total so far: 50500)
# Fetched 500 games (total so far: 51000)
# Fetched 500 games (total so far: 51500)
# Fetched 500 games (total so far: 52000)
# Fetched 500 games (total so far: 52500)
# Fetched 500 games (total so far: 53000)
# Fetched 500 games (total so far: 53500)
# Fetched 500 games (total so far: 54000)
# Fetched 500 games (total so far: 54500)
# Fetched 500 games (total so far: 55000)
# Fetched 500 games (total so far: 55500)
# Fetched 500 games (total so far: 56000)
# Fetched 500 games (total so far: 56500)
# Fetched 500 games (total so far: 57000)
# Fetched 500 games (total so far: 57500)
# Fetched 500 games (total so far: 58000)
# Fetched 500 games (total so far: 58500)
# Fetched 500 games (total so far: 59000)
# Fetched 500 games (total so far: 59500)
# Fetched 500 games (total so far: 60000)
# Fetched 500 games (total so far: 60500)
# Fetched 500 games (total so far: 61000)
# Fetched 500 games (total so far: 61500)
# Fetched 500 games (total so far: 62000)
# Fetched 500 games (total so far: 62500)
# Fetched 500 games (total so far: 63000)
# Fetched 500 games (total so far: 63500)
# Fetched 500 games (total so far: 64000)
# Fetched 500 games (total so far: 64500)
# Fetched 500 games (total so far: 65000)
# Fetched 500 games (total so far: 65500)
# Fetched 500 games (total so far: 66000)
# Fetched 500 games (total so far: 66500)
# Fetched 500 games (total so far: 67000)
# Fetched 500 games (total so far: 67500)
# Fetched 500 games (total so far: 68000)
# Fetched 500 games (total so far: 68500)
# Fetched 500 games (total so far: 69000)
# Fetched 500 games (total so far: 69500)
# Fetched 500 games (total so far: 70000)
# Fetched 500 games (total so far: 70500)
# Fetched 500 games (total so far: 71000)
# Fetched 500 games (total so far: 71500)
# Fetched 500 games (total so far: 72000)
# Fetched 500 games (total so far: 72500)
# Fetched 500 games (total so far: 73000)
# Fetched 500 games (total so far: 73500)
# Fetched 500 games (total so far: 74000)
# Fetched 500 games (total so far: 74500)
# Fetched 500 games (total so far: 75000)
# Fetched 500 games (total so far: 75500)
# Fetched 500 games (total so far: 76000)
# Fetched 500 games (total so far: 76500)
# Fetched 500 games (total so far: 77000)
# Fetched 500 games (total so far: 77500)
# Fetched 500 games (total so far: 78000)
# Fetched 500 games (total so far: 78500)
# Fetched 500 games (total so far: 79000)
# Fetched 500 games (total so far: 79500)
# Fetched 500 games (total so far: 80000)
# Fetched 500 games (total so far: 80500)
# Fetched 500 games (total so far: 81000)
# Fetched 500 games (total so far: 81500)
# Fetched 500 games (total so far: 82000)
# Fetched 500 games (total so far: 82500)
# Fetched 500 games (total so far: 83000)
# Fetched 500 games (total so far: 83500)
# Fetched 500 games (total so far: 84000)
# Fetched 500 games (total so far: 84500)
# Fetched 500 games (total so far: 85000)
# Fetched 500 games (total so far: 85500)
# Fetched 500 games (total so far: 86000)
# Fetched 500 games (total so far: 86500)
# Fetched 500 games (total so far: 87000)
# Fetched 500 games (total so far: 87500)
# Fetched 500 games (total so far: 88000)
# Fetched 500 games (total so far: 88500)
# Fetched 500 games (total so far: 89000)
# Fetched 500 games (total so far: 89500)
# Fetched 500 games (total so far: 90000)
# Fetched 500 games (total so far: 90500)
# Fetched 500 games (total so far: 91000)
# Fetched 500 games (total so far: 91500)
# Fetched 500 games (total so far: 92000)
# Fetched 500 games (total so far: 92500)
# Fetched 500 games (total so far: 93000)
# Fetched 500 games (total so far: 93500)
# Fetched 500 games (total so far: 94000)
# Fetched 500 games (total so far: 94500)
# Fetched 500 games (total so far: 95000)
# Fetched 500 games (total so far: 95500)
# Fetched 500 games (total so far: 96000)
# Fetched 500 games (total so far: 96500)
# Fetched 500 games (total so far: 97000)
# Fetched 500 games (total so far: 97500)
# Fetched 500 games (total so far: 98000)
# Fetched 500 games (total so far: 98500)
# Fetched 500 games (total so far: 99000)
# Fetched 500 games (total so far: 99500)
# Fetched 500 games (total so far: 100000)
# Fetched 500 games (total so far: 100500)
# Fetched 500 games (total so far: 101000)
# Fetched 500 games (total so far: 101500)
# Fetched 500 games (total so far: 102000)
# Fetched 500 games (total so far: 102500)
# Fetched 500 games (total so far: 103000)
# Fetched 500 games (total so far: 103500)
# Fetched 500 games (total so far: 104000)
# Fetched 500 games (total so far: 104500)
# Fetched 500 games (total so far: 105000)
# Fetched 500 games (total so far: 105500)
# Fetched 500 games (total so far: 106000)
# Fetched 500 games (total so far: 106500)
# Fetched 500 games (total so far: 107000)
# Fetched 500 games (total so far: 107500)
# Fetched 500 games (total so far: 108000)
# Fetched 500 games (total so far: 108500)
# Fetched 500 games (total so far: 109000)
# Fetched 500 games (total so far: 109500)
# Fetched 500 games (total so far: 110000)
# Fetched 500 games (total so far: 110500)
# Fetched 500 games (total so far: 111000)
# Fetched 500 games (total so far: 111500)
# Fetched 500 games (total so far: 112000)
# Fetched 500 games (total so far: 112500)
# Fetched 500 games (total so far: 113000)
# Fetched 500 games (total so far: 113500)
# Fetched 500 games (total so far: 114000)
# Fetched 500 games (total so far: 114500)
# Fetched 500 games (total so far: 115000)
# Fetched 500 games (total so far: 115500)
# Fetched 500 games (total so far: 116000)
# Fetched 500 games (total so far: 116500)
# Fetched 500 games (total so far: 117000)
# Fetched 500 games (total so far: 117500)
# Fetched 500 games (total so far: 118000)
# Fetched 500 games (total so far: 118500)
# Fetched 500 games (total so far: 119000)
# Fetched 500 games (total so far: 119500)
# Fetched 500 games (total so far: 120000)
# Fetched 500 games (total so far: 120500)
# Fetched 500 games (total so far: 121000)
# Fetched 500 games (total so far: 121500)
# Fetched 500 games (total so far: 122000)
# Fetched 500 games (total so far: 122500)
# Fetched 500 games (total so far: 123000)
# Fetched 500 games (total so far: 123500)
# Fetched 500 games (total so far: 124000)
# Fetched 500 games (total so far: 124500)
# Fetched 500 games (total so far: 125000)
# Fetched 500 games (total so far: 125500)
# Fetched 500 games (total so far: 126000)
# Fetched 500 games (total so far: 126500)
# Fetched 500 games (total so far: 127000)
# Fetched 500 games (total so far: 127500)
# Fetched 500 games (total so far: 128000)
# Fetched 500 games (total so far: 128500)
# Fetched 500 games (total so far: 129000)
# Fetched 500 games (total so far: 129500)
# Fetched 500 games (total so far: 130000)
# Fetched 500 games (total so far: 130500)
# Fetched 500 games (total so far: 131000)
# Fetched 500 games (total so far: 131500)
# Fetched 500 games (total so far: 132000)
# Fetched 500 games (total so far: 132500)
# Fetched 500 games (total so far: 133000)
# Fetched 500 games (total so far: 133500)
# Fetched 500 games (total so far: 134000)
# Fetched 500 games (total so far: 134500)
# Fetched 500 games (total so far: 135000)
# Fetched 500 games (total so far: 135500)
# Fetched 500 games (total so far: 136000)
# Fetched 500 games (total so far: 136500)
# Fetched 500 games (total so far: 137000)
# Fetched 500 games (total so far: 137500)
# Fetched 500 games (total so far: 138000)
# Fetched 500 games (total so far: 138500)
# Fetched 500 games (total so far: 139000)
# Fetched 500 games (total so far: 139500)
# Fetched 500 games (total so far: 140000)
# Fetched 500 games (total so far: 140500)
# Fetched 500 games (total so far: 141000)
# Fetched 500 games (total so far: 141500)
# Fetched 500 games (total so far: 142000)
# Fetched 500 games (total so far: 142500)
# Fetched 500 games (total so far: 143000)
# Fetched 500 games (total so far: 143500)
# Fetched 500 games (total so far: 144000)
# Fetched 500 games (total so far: 144500)
# Fetched 500 games (total so far: 145000)
# Fetched 500 games (total so far: 145500)
# Fetched 500 games (total so far: 146000)
# Fetched 500 games (total so far: 146500)
# Fetched 500 games (total so far: 147000)
# Fetched 500 games (total so far: 147500)
# Fetched 500 games (total so far: 148000)
# Fetched 53 games (total so far: 148053)
# Done! Total games fetched: 148053

# %%
game_ids = [g['id'] for g in all_games]

#popularity_primitives endpoint
def get_popularity_data(game_ids_batch):
    id_list = ','.join(map(str, game_ids_batch))
    query = f'''
    fields game_id, value, external_popularity_source, popularity_type;
    where game_id = ({id_list});
    '''
    byte_array = wrapper.api_request('popularity_primitives', query)
    return json.loads(byte_array.decode('utf-8'))

popularity_records = []
batch_size = 200
for i in range(0, len(game_ids), batch_size):
    batch = game_ids[i:i+batch_size]
    popularity_records.extend(get_popularity_data(batch))
    time.sleep(0.2)

# Convert dict to game_id
popularity_dict = {r['game_id']: r for r in popularity_records}

# Merged to all_games
for game in all_games:
    gid = game['id']
    record = popularity_dict.get(gid, {})
    game['popularity_score'] = record.get('value')
    game['popularity_source_id'] = record.get('external_popularity_source')
    game['popularity_type_id'] = record.get('popularity_type')

# %%
#To reduce loading time for each cell, remove games that do not have a popularity score available.
all_games = [g for g in all_games if g.get('popularity_score') is not None]
print(f"Total games in list: {len(all_games)}")
# Out:
# Total games in list: 2277

# %%
#get information related to game data time
game_ids = [g['id'] for g in all_games]

def get_time_to_beat_data(game_ids_batch):
    id_list = ','.join(map(str, game_ids_batch))
    query = f'''
    fields game_id, normally, hastily, completely, count;
    where game_id = ({id_list});
    '''
    byte_array = wrapper.api_request('game_time_to_beats', query)
    return json.loads(byte_array.decode('utf-8'))


time_to_beat_records = []
batch_size = 200
for i in range(0, len(game_ids), batch_size):
    batch = game_ids[i:i+batch_size]
    time_to_beat_records.extend(get_time_to_beat_data(batch))
    time.sleep(0.2)


ttb_dict = {r['game_id']: r for r in time_to_beat_records}

# merge the gametime back to all games list
for game in all_games:
    ttb = ttb_dict.get(game['id'], {})
    game['ttb_normally'] = ttb.get('normally')
    game['ttb_hastily'] = ttb.get('hastily')
    game['ttb_completely'] = ttb.get('completely')
    game['ttb_submission_count'] = ttb.get('count')

# %%
# Get Genre list
query = '''
fields id, name;
limit 500;
'''
byte_array = wrapper.api_request('genres', query)
genre_list = json.loads(byte_array.decode('utf-8'))

# genre to game id
genre_dict = {g['id']: g['name'] for g in genre_list}

# Convert genre ID list to name list
for game in all_games:
    genre_ids = game.get('genres')
    if not isinstance(genre_ids, list):
        genre_ids = []
    game['genre_names'] = [genre_dict.get(i, 'unknown') for i in genre_ids]

# %%
df = pd.DataFrame(all_games)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2277 entries, 0 to 2276
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2277 non-null   int64
#  1   aggregated_rating        1060 non-null   float64
#  2   aggregated_rating_count  1060 non-null   float64
#  3   first_release_date       2248 non-null   float64
#  4   genres                   2243 non-null   object
#  5   name                     2277 non-null   object
#  6   rating                   1546 non-null   float64
#  7   rating_count             1546 non-null   float64
#  8   total_rating             1718 non-null   float64
#  9   total_rating_count       1718 non-null   float64
#  10  game_type                2277 non-null   int64
#  11  popularity_score         2277 non-null   float64
#  12  popularity_source_id     2277 non-null   int64
#  13  popularity_type_id       2277 non-null   int64
#  14  ttb_normally             79 non-null     float64
#  15  ttb_hastily              49 non-null     float64
#  16  ttb_completely           61 non-null     float64
#  17  ttb_submission_count     106 non-null    float64
#  18  genre_names              2277 non-null   object
# dtypes: float64(12), int64(4), object(3)
# memory usage: 338.1+ KB

# %%
df.to_csv("pc_games_igdb .csv", index=False, encoding='utf-8')
